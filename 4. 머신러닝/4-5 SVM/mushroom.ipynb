# %%
import numpy as np
import pandas as pd
from sklearn import svm, metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
tbl = pd.read_csv('./mushrooms.csv', index_col=0)

# %%
tbl
# Out:
#       cap-shape cap-surface cap-color bruises odor gill-attachment  \
# class
# p             x           s         n       t    p               f
# e             x           s         y       t    a               f
# e             b           s         w       t    l               f
# p             x           y         w       t    p               f
# e             x           s         g       f    n               f
# e             x           y         y       t    a               f
# e             b           s         w       t    a               f
# e             b           y         w       t    l               f
# p             x           y         w       t    p               f
# e             b           s         y       t    a               f
# e             x           y         y       t    l               f
# e             x           y         y       t    a               f
# e             b           s         y       t    a               f
# ...

# %%
# https://datascienceschool.net/view-notebook/f43be7d6515b48c0beb909826993c856/
# 라벨을 정수로 변환
LE = LabelEncoder()
y = LE.fit_transform(tbl.index)

# 각 컬럼도 역시 정수로 변환
for column_name in tbl.columns:
    tbl[column_name] = LE.fit_transform(tbl[column_name])

# %%
tbl
# Out:
#        cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# class
# p              5            2          4        1     6                1
# e              5            2          9        1     0                1
# e              0            2          8        1     3                1
# p              5            3          8        1     6                1
# e              5            2          3        0     5                1
# e              5            3          9        1     0                1
# e              0            2          8        1     0                1
# e              0            3          8        1     3                1
# p              5            3          8        1     6                1
# e              0            2          9        1     0                1
# e              5            3          9        1     3                1
# e              5            3          9        1     0                1
# ...

# %%
y
# Out:
# array([1, 0, 0, ..., 0, 1, 0], dtype=int32)

# %%
# 트레이닝 데이터, 테스트 데이터로 나누기
data_train, data_test, label_train, label_test = train_test_split(tbl, y)

# %%
# SVM 학습
clf = svm.SVC()
clf.fit(data_train, label_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
# 데이터 예측
predict = clf.predict(data_test)

# %%
ac_score = metrics.accuracy_score(label_test, predict)
cl_report = metrics.classification_report(label_test, predict)
print(ac_score)
print(cl_report)
# Out:
# 1.0
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      1046
#           1       1.00      1.00      1.00       985
#
# avg / total       1.00      1.00      1.00      2031
