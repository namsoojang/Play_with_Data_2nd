# %%
import os, glob, json
root_dir = "./newstext"
dic_file = root_dir + "/word-dic.json"
data_file = root_dir + "/data.json"
data_file_min = root_dir + "/data-mini.json"

# %%
# 어구를 자르고 ID로 변환하기 ---(※1)
word_dic = { "_MAX": 0 }

def text_to_ids(text):
    text = text.strip()
    words = text.split(" ")
    result = []
    for n in words:
        n = n.strip()
        if n == "": continue
        if not n in word_dic:
            wid = word_dic[n] = word_dic["_MAX"]
            word_dic["_MAX"] += 1
            print(wid, n)
        else:
            wid = word_dic[n]
        result.append(wid)
    return result

# %%
# 파일을 읽고 고정 길이의 배열 리턴하기 ---(※2)
def file_to_ids(fname):
    with open(fname, "r") as f:
        text = f.read()
        return text_to_ids(text)

# %%
# 딕셔너리에 단어 모두 등록하기 --- (※3)
def register_dic():
    files = glob.glob(root_dir+"/*/*.wakati", recursive=True)
    for i in files:
        file_to_ids(i)

# %%
# 파일 내부의 단어 세기 --- (※4)
def count_file_freq(fname):
    cnt = [0 for n in range(word_dic["_MAX"])]
    with open(fname,"r") as f:
        text = f.read().strip()
        ids = text_to_ids(text)
        for wid in ids:
            cnt[wid] += 1
    return cnt

# %%
# 카테고리마다 파일 읽어 들이기 --- (※5)
def count_freq(limit = 0):
    X = []
    Y = []
    max_words = word_dic["_MAX"]
    cat_names = []
    print('os.listdir(root_dir)',os.listdir(root_dir))   # ['data-mini.json', 'data.json', 'word-dic.json']    #폴더내 파일 조회
    for cat in os.listdir(root_dir):
        cat_dir = root_dir + "/" + cat
        if not os.path.isdir(cat_dir): continue
        cat_idx = len(cat_names)
        cat_names.append(cat)
        files = glob.glob(cat_dir+"/*.wakati")
        i = 0
        for path in files:
            print(path)
            cnt = count_file_freq(path)
            X.append(cnt)
            Y.append(cat_idx)
            if limit > 0:
                if i > limit: break
                i += 1
    return X,Y

# %%
# 단어 딕셔너리 만들기 --- (※5)
if os.path.exists(dic_file):
    word_dic = json.load(open(dic_file))
else:
    register_dic()
    json.dump(word_dic, open(dic_file,"w"))

# %%
word_dic
# Out:
# {'_MAX': 56681,
#  '대다': 0,
#  '대선': 1,
#  '후보': 2,
#  '역대': 3,
#  '최': 4,
#  '명': 5,
#  '등록': 6,
#  '오다': 7,
#  '월': 8,
#  '일': 9,
#  '실시': 10,
#  '되다': 11,
#  '대통령': 12,
#  '선거': 13,
#  '가장': 14,
#  '많다': 15,
#  '하다': 16,
#  '중앙': 17,
#  '관리': 18,
#  '위원회': 19,
#  '마감': 20,
#  '결과': 21,
#  '더불다': 22,
#  '민주당': 23,
#  '문재인': 24,
#  '국민의당': 25,
#  '안철수': 26,
#  '자유': 27,
#  '한국': 28,
#  '홍준표': 29,
#  '바르다': 30,
#  '정당': 31,
#  '유승민': 32,
#  '정의당': 33,
#  '심상정': 34,
#  '등': 35,
#  '주요': 36,
#  '개': 37,
#  '비롯': 38,
#  '밝히다': 39,
#  '모두': 40,
#  '첫날': 41,
#  '서류': 42,
#  '접수': 43,
#  '안': 44,
#  '유': 45,
#  '직접': 46,
#  '선관위': 47,
#  '청사': 48,
#  '방문': 49,
#  '재산': 50,
#  '납세': 51,
#  '병역': 52,
#  '신상': 53,
#  '정보': 54,
#  '제출': 55,
#  '현황': 56,
#  '보다': 57,
#  '억': 58,
#  '만원': 59,
#  '이다': 60,
#  '홍': 61,
#  '문': 62,
#  '심': 63,
#  '순': 64,
#  '또': 65,
#  '군소': 66,
#  '주자': 67,
#  '가운데': 68,
#  '새누리당': 69,
#  '조원진': 70,
#  '늘': 71,
#  '푸른': 72,
#  '이재오': 73,
#  '민중': 74,
#  '연합': 75,
#  '김선동': 76,
#  '국민대': 77,
#  '통합': 78,
#  '장성민': 79,
#  '국민당': 80,
#  '이경희': 81,
#  '홍익': 82,
#  '윤홍식': 83,
#  '한반도': 84,
#  '미래연합': 85,
#  '김정선': 86,
#  '무소속': 87,
#  '김민찬': 88,
#  '통일한국': 89,
#  '남재준': 90,
#  '경제': 91,
#  '애국': 92,
#  '오': 93,
#  '영국': 94,
#  '추가': 95,
#  '사상': 96,
#  '숫자': 97,
#  '종전': 98,
#  '각각': 99,
#  '나서다': 100,
#  '년': 101,
#  '최대': 102,
#  '규모': 103,
#  '투표': 104,
#  '용지': 105,
#  '길이': 106,
#  '통틀어': 107,
#  '길어지다': 108,
#  '전망': 109,
#  '㎝': 110,
#  '달': 111,
#  '공직선거법': 112,
#  '기탁금': 113,
#  '억원': 114,
#  '받다': 115,
#  '최종': 116,
#  '득표율': 117,
#  '이상': 118,
#  '기록': 119,
#  '전액': 120,
#  '∼': 121,
#  '를': 122,
#  '반액': 123,
#  '보전': 124,
#  '해주다': 125,
#  '추천': 126,
#  '후보자': 127,
#  '약': 128,
#  '보조금': 129,
#  '배분': 130,
#  '강준구': 131,
#  '기자': 132,
#  '국민일보': 133,
#  '홈페이지': 134,
#  '페이스북': 135,
#  '트위터': 136,
#  '취재': 137,
#  '대행': 138,
#  '소': 139,
#  '왱': 140,
#  '클릭': 141,
#  'GoodNews': 142,
#  'paper': 143,
#  '무단': 144,
#  '전재': 145,
#  '및': 146,
#  '재': 147,
#  '배포': 148,
#  '금지': 149,
#  '포커스': 150,
#  '적폐': 151,
#  '패권': 152,
#  '강점': 153,
#  '부각': 154,
#  '아니다': 155,
#  '상대': 156,
#  '깎다': 157,
#  '리기': 158,
#  '득': 159,
#  '실': 160,
#  'ㆍ': 161,
#  '프레임': 162,
#  '전쟁': 163,
#  '계파': 164,
#  '갈등': 165,
#  '보수': 166,
#  '연대': 167,
#  '가능성': 168,
#  '끄다': 169,
#  '집다': 170,
#  '부정': 171,
#  '인식': 172,
#  '확산': 173,
#  '심판': 174,
#  '론': 175,
#  '몰락': 176,
#  '반사': 177,
#  '효과': 178,
#  '한계': 179,
#  '봉착': 180,
#  '것': 181,
#  '지적': 182,
#  '박정희': 183,
#  '묘역': 184,
#  '놓이다': 185,
#  '조화': 186,
#  '서울': 187,
#  '동작구': 188,
#  '국립서울현충원': 189,
#  '전': 190,
#  '있다': 191,
#  '김기남': 192,
#  '와': 193,
#  '의': 194,
#  '시작': 195,
#  '돼다': 196,
#  '두': 197,
#  '사람': 198,
#  '정치': 199,
#  '명운': 200,
#  '걸다': 201,
#  '이번': 202,
#  '불과': 203,
#  '달여': 204,
#  '남지': 205,
#  '않다': 206,
#  '상황': 207,
#  '상대방': 208,
#  '약점': 209,
#  '파고': 210,
#  '들다': 211,
#  '방점': 212,
#  '두다': 213,
#  '진영': 214,
#  '거론': 215,
#  '딱지': 216,
#  '붙이다': 217,
#  '비문': 218,
#  '인사': 219,
#  '로부터': 220,
#  '배타': 221,
#  '비판': 222,
#  '점': 223,
#  '규정': 224,
#  '이': 225,
#  '같다': 226,
#  '자신': 227,
#  '대한': 228,
#  '시키다': 229,
#  '의도': 230,
#  '크다': 231,
#  '나오다': 232,
#  '윤희': 233,
#  '웅': 234,
#  '피니언': 235,
#  '라이브': 236,
#  '여론': 237,
#  '분석': 238,
#  '센터': 239,
#  '주장': 240,
#  '얻다': 241,
#  '말': 242,
#  '지난': 243,
#  '수락': 244,
#  '연설': 245,
#  '반문': 246,
#  '정권': 247,
#  '교체': 248,
#  '겁': 249,
#  '내다': 250,
#  '저': 251,
#  '두려워하다': 252,
#  '박근혜': 253,
#  '최순실': 254,
#  '게이트': 255,
#  '드러나다': 256,
#  '곳곳': 257,
#  '개혁': 258,
#  '높다': 259,
#  '정치권': 260,
#  '용': 261,
#  '인위': 262,
#  '단일': 263,
#  '화가': 264,
#  '이름': 265,
#  '횡행': 266,
#  '현실': 267,
#  '겨냥': 268,
#  '발언': 269,
#  '해석': 270,
#  '최근': 271,
#  '지지율': 272,
#  '상승세': 273,
#  '타고': 274,
#  '문안': 275,
#  '양강': 276,
#  '구도': 277,
#  '전제': 278,
#  '일부': 279,
#  '여론조사': 280,
#  '앞서다': 281,
#  '선': 282,
#  '중도': 283,
#  '사퇴': 284,
#  '따르다': 285,
#  '대결': 286,
#  '부담스럽다': 287,
#  '시나리오': 288,
#  '측': 289,
#  '향': 290,
#  '손잡다': 291,
#  '편': 292,
#  '설': 293,
#  '세력': 294,
#  '연장': 295,
#  '분명하다': 296,
#  '김태년': 297,
#  '의원': 298,
#  '고': 299,
#  '거듭': 300,
#  '요구': 301,
#  '배경': 302,
#  '분열': 303,
#  '주의': 304,
#  '극복': 305,
#  '지다': 306,
#  '지난해': 307,
#  '총선': 308,
#  '친노': 309,
#  '새정치': 310,
#  '민주': 311,
#  '탈당': 312,
#  '탄핵': 313,
#  '친박': 314,
#  '높아지다': 315,
#  '내': 316,
#  '친문': 317,
#  '그룹': 318,
#  '양': 319,
#  '몰다': 320,
#  '차별': 321,
#  '양쪽': 322,
#  '허다': 323,
#  '갖다': 324,
#  '계속': 325,
#  '거리': 326,
#  '면서': 327,
#  '이어지다': 328,
#  '경우': 329,
#  '명분': 330,
#  '약해지다': 331,
#  '반대': 332,
#  '면죄부': 333,
#  '주다': 334,
#  '특정': 335,
#  '위': 336,
#  '그으다': 337,
#  '그렇다': 338,
#  '국민': 339,
#  '강조': 340,
#  '인물': 341,
#  '정책': 342,
#  '승부': 343,
#  '스스로': 344,
#  '끌다': 345,
#  '올리다': 346,
#  '자강': 347,
#  '기반': 348,
#  '설득': 349,
#  '구호': 350,
#  '멀다': 351,
#  '자체': 352,
#  '호남': 353,
#  '편중': 354,
#  '심하다': 355,
#  '민심': 356,
#  '기대다': 357,
#  '경향': 358,
#  '지역': 359,
#  '부추': 360,
#  '기다': 361,
#  '처지': 362,
#  '무엇': 363,
#  '네거티브': 364,
#  '싸움': 365,
#  '간다': 366,
#  '문제': 367,
#  '윤': 368,
#  '지금': 369,
#  '정도': 370,
#  '몰르다': 371,
#  '이후': 372,
#  '확장': 373,
#  '높이다': 374,
#  '위해': 375,
#  '본인': 376,
#  '포지티브': 377,
#  '필요하다': 378,
#  '보이다': 379,
#  '덧붙이다': 380,
#  '이주영': 381,
#  '경향신문': 382,
#  'SNS': 383,
#  '인기': 384,
#  '무료': 385,
#  '만화': 386,
#  '보기': 387,
#  '©': 388,
#  '정우택': 389,
#  '劉': 390,
#  '세월호': 391,
#  '선장': 392,
#  '뛰어나가다': 393,
#  '인륜': 394,
#  '버리다': 395,
#  '배신': 396,
#  '대표': 397,
#  '권한': 398,
#  '사진': 399,
#  '공식': 400,
#  '아시아': 401,
#  '부산': 402,
#  '김보경': 403,
#  '채석': 404,
#  '정': 405,
#  '조준': 406,
#  '라며': 407,
#  '자기': 408,
#  '발탁': 409,
#  '이끌다': 410,
#  '준': 411,
#  '그': 412,
#  '어리다': 413,
#  '때': 414,
#  '언제': 415,
#  '듯': 416,
#  '돌리다': 417,
#  '게': 418,
#  '배반': 419,
#  '공세': 420,
#  '가하다': 421,
#  '날': 422,
#  '울산': 423,
#  '삼산동': 424,
#  '근로자': 425,
#  '종합': 426,
#  '복지': 427,
#  '회관': 428,
#  '열리다': 429,
#  '대위': 430,
#  '발대식': 431,
#  '필승': 432,
#  '결의': 433,
#  '대회': 434,
#  '에서': 435,
#  '어제': 436,
#  '대구': 437,
#  '경북': 438,
#  'TK': 439,
#  '행사': 440,
#  '전날': 441,
#  '뭐라다': 442,
#  '다녀가다': 443,
#  '적자': 444,
#  '며': 445,
#  '소개': 446,
#  '초': 447,
#  '중': 448,
#  '고등학교': 449,
#  '시절': 450,
#  '서문시장': 451,
#  '뛰어놀다': 452,
#  '자칭': 453,
#  '망나니': 454,
#  '별명': 455,
#  '분': 456,
#  '어떻다': 457,
#  '적다': 458,
#  '물다': 459,
#  '또한': 460,
#  '자랑스럽다': 461,
#  '정말': 462,
#  '어렵다': 463,
#  '고비': 464,
#  '넘기다': 465,
#  '새': 466,
#  '날개': 467,
#  '날다': 468,
#  '오른쪽': 469,
#  '부서지다': 470,
#  '적통': 471,
#  '제대로': 472,
#  '대한민국': 473,
#  '호가': 474,
#  '갈다': 475,
#  '수': 476,
#  '불의': 477,
#  '판': 478,
#  '치다': 479,
#  '세상': 480,
#  '가다': 481,
#  '사회': 482,
#  '없어지다': 483,
#  '부정부패': 484,
#  '타협': 485,
#  '정의': 486,
#  '나라': 487,
#  '만들다': 488,
#  '지지': 489,
#  '호소': 490,
#  '수습': 491,
#  '모든': 492,
#  '재미': 493,
#  '티잼': 494,
#  '카드': 495,
#  '뉴스': 496,
#  '오늘': 497,
#  '운세': 498,
#  '세계': 499,
#  '창': 500,
#  '눈': 501,
#  '사드': 502,
#  '국면': 503,
#  '맞다': 504,
#  '나미': 505,
#  '감정': 506,
#  '대립': 507,
#  '표': 508,
#  '추다': 509,
#  '자제': 510,
#  '도널드': 511,
#  '트럼프': 512,
#  '미국': 513,
#  '황교안': 514,
#  '통화': 515,
#  '밉다': 516,
#  '정상회담': 517,
#  '시': 518,
#  'THAAD': 519,
#  '고고': 520,
#  '미사일방어': 521,
#  '체계': 522,
#  '관련': 523,
#  '입장': 524,
#  '전달': 525,
#  '새롭다': 526,
#  '황': 527,
#  '회담': 528,
#  '사안': 529,
#  '상당': 530,
#  '시간': 531,
#  '할애': 532,
#  '한미': 533,
#  '동맹': 534,
#  '중요하다': 535,
#  '시진핑': 536,
#  '習近平': 537,
#  '국가주석': 538,
#  '충분하다': 539,
#  '울다': 540,
#  '북핵': 541,
#  '북한': 542,
#  '심각': 543,
#  '대응': 544,
#  '방향': 545,
#  '대해': 546,
#  '심다': 547,
#  '논의': 548,
#  '가지다': 549,
#  '배치': 550,
#  '미측': 551,
#  '국무총리실': 552,
#  '관': 553,
#  '노력': 554,
#  '평가': 555,
#  '굳다': 556,
#  '함': 557,
#  '강력하다': 558,
#  '감': 559,
#  '다시': 560,
#  '한번': 561,
#  '확인': 562,
#  '뜻': 563,
#  '깊다': 564,
#  '계기': 565,
#  '그동안': 566,
#  '△': 567,
#  '핵': 568,
#  '미사일': 569,
#  '방어': 570,
#  '무기': 571,
#  '중국': 572,
#  '우려': 573,
#  '필요': 574,
#  '없다': 575,
#  '차원': 576,
#  '결정': 577,
#  '예정': 578,
#  '차질': 579,
#  '보복': 580,
#  '중단': 581,
#  '기본': 582,
#  '견지': 583,
#  '이렇다': 584,
#  '다만': 585,
#  '글로벌': 586,
#  '이슈': 587,
#  '얼마만큼': 588,
#  '강도': 589,
#  '얼마나': 590,
#  '집중': 591,
#  '불': 592,
#  '명확하다': 593,
#  '양국': 594,
#  '간': 595,
#  '차갑다': 596,
#  '축소': 597,
#  '보이': 598,
#  '주석': 599,
#  '사이': 600,
#  '견해': 601,
#  '좁히다': 602,
#  '일정하다': 603,
#  '절충': 604,
#  '찾다': 605,
#  '성과': 606,
#  '하나로': 607,
#  '직후': 608,
#  '이뤄지다': 609,
#  '렉스': 610,
#  '틸러슨': 611,
#  '국무부': 612,
#  '장관': 613,
#  '부처': 614,
#  '브리핑': 615,
#  '전혀': 616,
#  '언급': 617,
#  '비추다': 618,
#  '볼': 619,
#  '정상': 620,
#  '주고받다': 621,
#  '팽팽히': 622,
#  '맞서다': 623,
#  '배제': 624,
#  '매체': 625,
#  '오후': 626,
#  '현재': 627,
#  '보도': 628,
#  '당시': 629,
#  '버락': 630,
#  '마마': 631,
#  '극렬': 632,
#  '파열음': 633,
#  '나다': 634,
#  '비교': 635,
#  '오바마': 636,
#  '면전': 637,
#  '다른': 638,
#  '이익': 639,
#  '훼손': 640,
#  '좋다': 641,
#  '損人不利己': 642,
#  '손': 643,
#  '불리다': 644,
#  '외교부': 645,
#  '정쩌광': 646,
#  '鄭澤光': 647,
#  '부부': 648,
#  '차관': 649,
#  '김예진': 650,
#  '미디어': 651,
#  '일보': 652,
#  '洪': 653,
#  '왜곡': 654,
#  '재판': 655,
#  '준비': 656,
#  '하라': 657,
#  '청송군': 658,
#  '진보': 659,
#  '객주': 660,
#  '전통': 661,
#  '시장': 662,
#  '시민': 663,
#  '만나다': 664,
#  '대화': 665,
#  '나누다': 666,
#  '캠프': 667,
#  '제공': 668,
#  'News': 669,
#  '송원영': 670,
#  '친': 671,
#  '박다': 672,
#  '참여': 673,
#  '도로': 674,
#  '증명': 675,
#  '조만간': 676,
#  '사라지다': 677,
#  '제': 678,
#  '김정': 679,
#  '률': 680,
#  '경남': 681,
#  '도지사': 682,
#  '보궐선거': 683,
#  '없애다': 684,
#  '꼼수': 685,
#  '부리고': 686,
#  '일침': 687,
#  '칠성': 688,
#  '뒤': 689,
#  '이제': 690,
#  '바닥': 691,
#  '뒤집어지다': 692,
#  '확신': 693,
#  '앞서': 694,
#  '통해': 695,
#  '차다': 696,
#  '다수': 697,
#  '기관': 698,
#  '언론': 699,
#  '바': 700,
#  '출범': 701,
#  '김진태': 702,
#  '親': 703,
#  '계': 704,
#  '데': 705,
#  '한마디': 706,
#  '저런': 707,
#  '체제': 708,
#  '과연': 709,
#  '용서': 710,
#  '구': 711,
#  '의문': 712,
#  '완전하다': 713,
#  '무시': 714,
#  '채': 715,
#  '오만': 716,
#  '꾸리다': 717,
#  '곧': 718,
#  '뿐': 719,
#  '업다': 720,
#  '출마': 721,
#  '냉정': 722,
#  '빠르다': 723,
#  '올라가다': 724,
#  '자신감': 725,
#  '내비': 726,
#  '급상승': 727,
#  '층': 728,
#  '때문': 729,
#  '대하다': 730,
#  '누가': 731,
#  '아직': 732,
#  '박지원': 733,
#  '올라타다': 734,
#  '박': 735,
#  '상왕': 736,
#  '안보': 737,
#  '절대': 738,
#  '건전하다': 739,
#  '인정': 740,
#  '남다': 741,
#  '기간': 742,
#  '동안': 743,
#  '우뚝': 744,
#  '서서': 745,
#  '상대로': 746,
#  '치르다': 747,
#  '승산': 748,
#  '선제': 749,
#  '타격': 750,
#  '미군': 751,
#  '핵공격': 752,
#  '징후': 753,
#  '임박': 754,
#  '합의': 755,
#  '우리': 756,
#  '동의': 757,
#  '오랫동안': 758,
#  '고민': 759,
#  '해오다': 760,
#  '국가': 761,
#  '불안하다': 762,
#  '흔들리다': 763,
#  '쓰나미': 764,
#  '벗다': 765,
#  '미래': 766,
#  '책임지다': 767,
#  '생각': 768,
#  '한편': 769,
#  '소감': 770,
#  '역전': 771,
#  '나가다': 772,
#  '최선': 773,
#  '다하다': 774,
#  '승리': 775,
#  'jrkim': 776,
#  '놓치다': 777,
#  '후회': 778,
#  '최신': 779,
#  '나': 780,
#  '여러분': 781,
#  '제보': 782,
#  '기다리다': 783,
#  '코리아': 784,
#  'news': 785,
#  'kr': 786,
#  '마크': 787,
#  '맨': 788,
#  '수도권': 789,
#  '경선': 790,
#  '뒷이야기': 791,
#  '앵커': 792,
#  '막바지': 793,
#  '요': 794,
#  '내일': 795,
#  '모레': 796,
#  '남기다': 797,
#  '코너': 798,
#  '부': 799,
#  '정제': 800,
#  '좀': 801,
#  '본선': 802,
#  '직행': 803,
#  '결선': 804,
#  '가늘다': 805,
#  '현장': 806,
#  '분위기': 807,
#  '일단': 808,
#  '바로': 809,
#  '매직': 810,
#  '넘버': 811,
#  '만': 812,
#  '무슨': 813,
#  '넘다': 814,
#  '거': 815,
#  '세': 816,
#  '번의': 817,
#  '평균': 818,
#  '감안': 819,
#  '최소': 820,
#  '가정': 821,
#  '이중': 822,
#  '수가': 823,
#  '겁니다': 824,
#  '반면': 825,
#  '지사': 826,
#  '이재명': 827,
#  '합산': 828,
#  '율': 829,
#  '생기다': 830,
#  '여기': 831,
#  '주력': 832,
#  '워낙': 833,
#  '선거인단': 834,
#  '뚜껑': 835,
#  '열다': 836,
#  '봐': 837,
#  '알': 838,
#  '안희정': 839,
#  '원래': 840,
#  '뿌리': 841,
#  'TV': 842,
#  '토론': 843,
#  '상당하다': 844,
#  '상한': 845,
#  '보': 846,
#  '느끼다': 847,
#  '어색하다': 848,
#  '몇': 849,
#  '번': 850,
#  '연출': 851,
#  '발표': 852,
#  '서로': 853,
#  '친밀': 854,
#  '축하': 855,
#  '수도': 856,
#  '형식': 857,
#  '악수': 858,
#  '헤어지다': 859,
#  '관계자': 860,
#  '간의': 861,
#  '신경': 862,
#  '전도': 863,
#  '꽤': 864,
#  '치열': 865,
#  '장': 866,
#  '드리다': 867,
#  '보시': 868,
#  '충청': 869,
#  '모습': 870,
#  '박영선': 871,
#  '충남지사': 872,
#  '멘토': 873,
#  '단장': 874,
#  '장면': 875,
#  '분간': 876,
#  '휴대전화': 877,
#  '포착': 878,
#  '그게': 879,
#  '꼭': 880,
#  '싫다': 881,
#  '다기': 882,
#  '전략': 883,
#  '짜다': 884,
#  '끝나다': 885,
#  '만약': 886,
#  '얘기': 887,
#  '라면': 888,
#  '서다': 889,
#  '먹다': 890,
#  '관계': 891,
#  '달리': 892,
#  '이기': 893,
#  '하나': 894,
#  '첫': 895,
#  '지인': 896,
#  '표정': 897,
#  '굉장하다': 898,
#  '밝다': 899,
#  '환하다': 900,
#  '웃다': 901,
#  '영남': 902,
#  '다르다': 903,
#  '담다': 904,
#  '짓다': 905,
#  '입': 906,
#  '직전': 907,
#  '다음': 908,
#  '그다음': 909,
#  '후배': 910,
#  '팀임': 911,
#  '벌써': 912,
#  '경험': 913,
#  '당': 914,
#  '지면': 915,
#  '손학규': 916,
#  '정세균': 917,
#  '김두관': 918,
#  '욕설': 919,
#  '야유': 920,
#  '심지어': 921,
#  '물병': 922,
#  '날아다니다': 923,
#  '소동': 924,
#  '책': 925,
#  '날아오다': 926,
#  '선출': 927,
#  '스탠드': 928,
#  '돌': 929,
#  '흔들다': 930,
#  '바보': 931,
#  '일정': 932,
#  '전철': 933,
#  '밟다': 934,
#  '측은': 935,
#  '원': 936,
#  '팀': 937,
#  '남아': 938,
#  '진행': 939,
#  '유대': 940,
#  '띄다': 941,
#  '목표': 942,
#  '둘': 943,
#  '힘': 944,
#  '모으다': 945,
#  '지지자': 946,
#  '찍다': 947,
#  '영상': 948,
#  '건가': 949,
#  '네': 950,
#  '오렌지색': 951,
#  '옷': 952,
#  '입다': 953,
#  '이분': 954,
#  '들이다': 955,
#  '외치': 956,
#  '왜': 957,
#  '불다': 958,
#  '도와주다': 959,
#  '사실': 960,
#  '꺼지다': 961,
#  '진짜': 962,
#  '드러내다': 963,
#  '조금': 964,
#  '편하다': 965,
#  '이야기': 966,
#  '저녁': 967,
#  '오랜만': 968,
#  '여유': 969,
#  '시청자': 970,
#  '자다': 971,
#  '모르다': 972,
#  '뭡': 973,
#  '밀착': 974,
#  '따라다니다': 975,
#  '예컨대': 976,
#  '잠깐': 977,
#  '앉다': 978,
#  '식사': 979,
#  '이전': 980,
#  '자리': 981,
#  '만들어지다': 982,
#  '풀이': 983,
#  '몰두': 984,
#  '압승': 985,
#  '기대': 986,
#  '득표': 987,
#  '활동': 988,
#  '더': 989,
#  '총력전': 990,
#  '펴다': 991,
#  'JTBC': 992,
#  '유튜브': 993,
#  'Copyright': 994,
#  'by': 995,
#  'and': 996,
#  'Content': 997,
#  'Hub': 998,
#  ...}

# %%
# 벡터를 파일로 출력하기 --- (※6)
# 테스트 목적의 소규모 데이터 만들기
X, Y = count_freq(20)
json.dump({"X": X, "Y": Y}, open(data_file_min,"w"))
# 전체 데이터를 기반으로 데이터 만들기
X, Y = count_freq()
print(X,Y)
json.dump({"X": X, "Y": Y}, open(data_file,"w"))
print("ok")
# Out:
# os.listdir(root_dir) ['data-mini.json', 'data.json', 'word-dic.json']
# os.listdir(root_dir) ['data-mini.json', 'data.json', 'word-dic.json']
# [] []
# ok
