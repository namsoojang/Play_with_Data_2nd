# %%
#qna게시판1개페이지 --> 링크 --> 링크별 질문/답변 저장
import requests
from bs4 import BeautifulSoup
import time

QNA_TYPES=["LAWYER", "DOCTOR", "ANIMALDOCTOR", "PHARMACIST", "DIETITIAN"]
#QNA_TYPES=["LAWYER", "DOCTOR", "LABOR", "ANIMALDOCTOR", "PHARMACIST", "TAXACC", "DIETITIAN"]
PAGE_START=1   #게시판 페이지 번호 
PAGE_END=2
EXPERT_NUMBER=30        #전문가 조사 숫자

board_page_pre="http://kin.naver.com/userinfo/expert/answerList.nhn?userId="
SPLIT_WORD="**********"
SPLIT_QNAS=" ###Q&A### "

USERID={"LAWYER":['winsosong', 'kin_lawtalk', 'tslawyer1', 'knslaw7', 'yoosb77', 'lawofficech', 'magol2', 'sbsclington', 'winsosong', 'redvaliant', 'qjqanhaneum', 'winsosong', 'rlarbqjadl1', 'tongkwon', 'brosaltclune', 'baek4128', 'hanbyungchul', 'kiryn7', 'bankruptcy1', 'law3149', 'jungsehyung', 'k33kor33', 'winsosong', 'yoonhs82', 'oklawcafe', 'coollawyer71', 'alka1031', 'pakjhak', 'choy2003', 'hunshabi', 'ksstar7', 'vidivici', 'ojikjeasus', 'winsosong', 'kangkkh98', 'nalnari7', 'parkdongsub', 'bhomme1111', 'kjhanlaw', 'ukhanl', 'lawyerlm', 'lawjdw', 'younq88', 'goodworld', 'winsosong', 'woolf3302', 'kohyg75', 'sangsock1n', 'bumani79', 'i_lawyer', 'macerate', 'iaminotyou', 'hellojo76', 'kwk131', 'jin138309', 'winsosong', 'davidlsg', 'hyosik72', 'jsy9311', 'heung1981', 'zephyr121', 'sw5339', 'smanchoi1', 'lwy526', 'hirte0', 'taejung3650', 'winsosong', 'cheese617', 'baeklaw', 'chkortoi', 'ujs77', 'zard1487', 'greatjkj', 'lawyer2107', 'hopelawpasan', 'watergiant82', 'lawyerboram', 'winsosong', 'yjm3786', 'choibeomjoon', 'lawyer2080', 'xeipper73', 'honeylsh1', 'gasigogy23', 'jytlawyer', 'topipop', 'seohalaw', 'auter1', 'winsosong', 'ssonglawyer', 'rights717', 'neofirepower', 'hmhlaw83', 'mogul509', 'lawyerpark83', 'antiwhitepig', 'yeri0207', '0318gunai', 'munsunglawyer'],\
           "DOCTOR":['succ27', 'doctorob', 'source43', 'papain21', 'jsyaz', 'mariana99', '9690067', 'sunnymun2000', 'cdbsbs', 'hykwonmd', 'vitals1', 'succ27', 'orange_eye', 'orangeclinic', 'spine4u', 'carespine', 'pskimjeehoon', 'akimo502', 'ksh12434', 'kodoc', 'chosk74', 'rnjs246', 'succ27', 'sasangdr', 'taelee73', 'itinku2', 'gnusni', 'healingtalky', 'final82', 'neversuffer', 'psdoctors', 'sc3011', 'presid50', 'succ27', 'rk_doctor', '82july07', 'prouduro1', 'dejavu7510', 'fcrealmadrid', 'hamajokw', 'jins0203', 'iwasborn4u', 'ljy5819', 'ihealth4u', 'succ27', 'woongya', 'duodocdj86', 'sedona7510', 'drnoguchi', 'woo8528jp', 'likeagle', 'oraclecdam', 'nireshin1', 'acemed', 'aba1022', 'succ27', 'skindrshw', 'choijh7011', 'kc386', 'ddongle7799', 'seranac1', 'ypainclinic', 'allis21', 'drderma', 'gogogia', 'han4636', 'succ27', 'hoboksun', 'fourlong', 'etern
', 'jpjw01', 'kim-sb', 'kwj8639', 'bonpoint1012', 'oursaver', 'dltmf0215', 'blueangels97', 'nsdiet0', 'mednutr', 'jewelike81', 'chaeyeon33na', 'ejl422', 'taisunhyun', 'eocn07', 'momlee1023', 'juheuis', 'yse0916', 'dilatatum222', 'rdjoo', 'gudy77', 'jnklim', 'chaeyeon33na', 'qkzy09', 'jsuns31', 'namehhj', 'freshsou', 'jizonmam', 'madoyeah', 'tnrud527', 'baehj0913', 'ekkim8184', 'gkswltmf7', 'chaeyeon33na', 'mina08267', 'younyjh87', 'jsseograce', 'rudgns8403', 'sullenelee', 'kjhdemc2004', 'madame801003', 'dietitian0609']}


def make_board_page(userid,pagenum):
    '''
    qna 게시판 url을 만든다
    '''
    board_page=board_page_pre+userid+"&page"+str(pagenum)
    return(board_page)


def get_html(url):
    '''
    url 주소 넣으면 html을 리턴한다
    '''
    user_agent="Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) " +\
        "AppleWebKit/537.36 (KHTML, like Gecko) " + \
        "Chrome/37.0.2062.94 Safari/537.36"
    headers = {"User-Agent": user_agent}
    response=requests.get(url, headers=headers)
    html=response.text
    return html

def get_qna_url(board_url):
    '''
    board_url을 넣으면 --> qna 20개의 ulr 주소, 소분류 리턴
    '''
    qna_urls=[]
    qna_urls_group=[]
    html_board=get_html(board_url)
    soup=BeautifulSoup(html_board,"lxml")
    for link in soup.select("td > a"):
        qna_urls.append(link)

    i=0
    while not i> len(qna_urls)-1:
        qna_urls_group.append(["http://kin.naver.com"+qna_urls[i]["href"],qna_urls[i+1].get_text()])
        i+=2
        
    return qna_urls_group      #url 주소와,소분류를 리턴해준다


def get_expert_qnas(qna_url):        
    '''
    QNA 페이지 url를 입력하면,  문의/답변을 리스트로  정리함. qnas[0]은 문의내용
    '''
    qnas=[]
    html_qna=get_html(qna_url)
    soup=BeautifulSoup(html_qna,"lxml")
    qnas_html=soup.find_all("div",class_="_endContentsText")
    for qna in qnas_html:
        qna_text=qna.get_text()
        qnas.append(qna_text.strip()+SPLIT_QNAS)
    time.sleep(1)
    return qnas

def make_file_name(qna_type,userid,pagenum):
    output_file="./qnas/"+qna_type+"_"+userid+"_page"+str(pagenum)+".txt"
    return output_file

def write_qnas(text_file,qnas):
    with open(text_file, "w", encoding="utf-8") as output_file:
        lines=qnas.split(SPLIT_WORD)
        for line in lines:
            print(line, file=output_file)
#qnas=[]

for qna_type in QNA_TYPES:
    for userid in USERID[qna_type][:EXPERT_NUMBER]:
        for pagenum in range(PAGE_START,PAGE_END):
            board_page=make_board_page(userid,pagenum)
            qna_urls=get_qna_url(board_page)
            qnas=""
            for qna_url in qna_urls:
                print(qna_url[0])
                qna=get_expert_qnas(qna_url[0])
                #qnas.append([qna_type,qna_url[1],qna])
                qnas_str="{}\t{}\t{}\t{}".format(qna_type, qna_url[1], qna,SPLIT_WORD)
                qnas+=qnas_str
                
                time.sleep(1) 
            text_file=make_file_name(qna_type,userid,pagenum)
            write_qnas(text_file,qnas)
            time.sleep(1)
# Out:
# http://kin.naver.com/qna/detail.nhn?d1id=6&dirId=60802&docId=271475023
# http://kin.naver.com/qna/detail.nhn?d1id=4&dirId=401030304&docId=271474368
# http://kin.naver.com/qna/detail.nhn?d1id=6&dirId=60802&docId=271474521
# http://kin.naver.com/qna/detail.nhn?d1id=6&dirId=60802&docId=271448685
# http://kin.naver.com/qna/detail.nhn?d1id=6&dirId=60802&docId=271449101
# http://kin.naver.com/qna/detail.nhn?d1id=6&dirId=60802&docId=271449176
# http://kin.naver.com/qna/detail.nhn?d1id=6&dirId=60802&docId=271451717
# http://kin.naver.com/qna/detail.nhn?d1id=6&dirId=60802&docId=271452705
# http://kin.naver.com/qna/detail.nhn?d1id=6&dirId=60802&docId=271453611
# http://kin.naver.com/qna/detail.nhn?d1id=6&dirId=60802&docId=271456409
# http://kin.naver.com/qna/detail.nhn?d1id=6&dirId=60802&docId=271456726
# http://kin.naver.com/qna/detail.nhn?d1id=6&dirId=60802&docId=271473212
# http://kin.naver.com/qna/detail.nhn?d1id=6&dirId=6080402&docId=271458411
# ...
