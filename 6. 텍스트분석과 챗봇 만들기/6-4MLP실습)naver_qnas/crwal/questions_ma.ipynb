# %%
'''
    qna_total 에서 분야별로 문의 글을 정리한다. 
'''

#QNA_TYPE="LAWYER"
QNA_TYPES=["LAWYER", "DOCTOR", "LABOR", "ANIMALDOCTOR", "PHARMACIST", "TAXACC", "DIETITIAN"]

def find_file_name(qna_type):
    input_file="./qnas_total/"+qna_type+"_total.txt"
    return input_file

def make_file_name(qna_type):
    output_file="./question_ma/"+qna_type+"_questions.txt"
    return output_file
    
def write_question(lines):
    with open(output_file, "w", encoding="utf-8") as output:
        for line in lines:
            print(line, file=output)        

for qna_type in QNA_TYPES:
    input_file=find_file_name(qna_type)
    output_file=make_file_name(qna_type)
    #input_file="./qnas/LABOR_cc3729k_page1.txt"
    questions=[]
    with open(input_file, "r", encoding="utf-8") as input_texts:
        for text in input_texts:
            text=text.strip()
            text=text.split("\t")
            if len(text)<2: continue             #공백이거나 질의응답이 없는 것은 제외한다. 
            question=text[2].split(" ###Q&A### ")[0]    
            if len(question)<10: continue
            questions.append(question)


    write_question(questions)

# %%
'''
    question의 ma 분석 진행
'''
import re
import ujson
from konlpy.tag import Komoran

QNA_TYPES=["LAWYER", "DOCTOR", "LABOR", "ANIMALDOCTOR", "PHARMACIST", "TAXACC", "DIETITIAN"]

def split_sentences(text):
    all_sentences=[]
    lines=text.strip()
    sentences=re.split("(?<=[.?!]) ",lines)
   
    return sentences

def get_morph_anal(analyzer,text):
    sent_morph_anals=[]
    sentences=split_sentences(text)
    
    for sentence in sentences:
        sent_morph_anal=analyzer.pos(sentence)
        sent_morph_anals.append(sent_morph_anal)
        
    json_obj={"ma_res": sent_morph_anals}
        
    return json_obj

def print_morph_anal(morph_anals, output_file):
    with open(output_file, "w", encoding="utf-8")as output:
        for morph_anal in morph_anals:
            print(ujson.dumps(morph_anal, ensure_ascii=False), file=output)
        print(type(morph_anals))
        
input_file="./question_ma/LABOR_questions.txt"
output_file="./question_ma/LABOR_questions_ma.txt"
komoran=Komoran()
ma_res=[]
with open(input_file, "r", encoding="utf-8")as input_texts:
    for text in input_texts:
        ma_re=get_morph_anal(komoran, text[2:])
        ma_res.append(ma_re)
    print(type(ma_res))
    print_morph_anal(ma_res,output_file)
# Out:
# <class 'list'>
# <class 'list'>

# %%
'''
    K-means 방법 활용하여 질문을 그룹화 한다. 
'''

import ujson
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

INPUT_FILE_NAME = "./question_ma/LABOR_questions_ma.txt"
FEATURE_POSES = ["NNG", "NNP", "XR"]
MA_KEY = "ma_res"
NUM_CLUSTERS = 40
QNA_TYPES=["LAWYER", "DOCTOR", "LABOR", "ANIMALDOCTOR", "PHARMACIST", "TAXACC", "DIETITIAN"]
qna_type="LABOR"

def make_file_name():
    output_file_name="./question_ma/"+qna_type+"_questions_ma_analy_"+str(NUM_CLUSTERS)+"Groups.txt"
    return output_file_name


def read_documents():
    documents = []

    with open(INPUT_FILE_NAME, "r", encoding="utf-8") as input_file:
        for line in input_file:
            morphs = []
            json_obj = ujson.loads(line)

            for sent_anal in json_obj[MA_KEY]:
                for morph_lex, morph_cat in sent_anal:
                    if morph_cat not in FEATURE_POSES:
                        continue

                    morphs.append(morph_lex)

            document = " ".join(morphs)
            documents.append(document)

    return documents


def build_doc_term_mat(documents):
    vectorizer = TfidfVectorizer()
    doc_term_mat = vectorizer.fit_transform(documents)
    words = vectorizer.get_feature_names()

    return doc_term_mat, words


def get_flat_clusters(doc_term_mat):
    km = KMeans(n_clusters=NUM_CLUSTERS, init="k-means++", verbose=1)    # 클러스터의 개수를 지정해주어야함!. 
                                                    # 점 찍는 곳에 따라 결과가 달라짐. k-means++ 가 점 찍는 방법. "random"도 있음
                                                    # verbose=1 : 반복작업을 화면에 보여달라. verbose=0: 화면 표시 하지 마라
    km.fit(doc_term_mat)

    return km


def print_centroid_words(model, words,output_file):
    print("군집별 중심 어휘")
    print()

    ordered_centroids = model.cluster_centers_.argsort()[:, ::-1]    # argsort() value로 sort 하지만, 결과는 ID 로 하라는 의미. 
                                                                        # [:, ::-1] --> 역순 정렬하라. 
    with open(output_file,"w",encoding="utf-8") as output:

        for cluster_num in range(NUM_CLUSTERS):
            center_word_nums = []

            for word_num in ordered_centroids[cluster_num, :20]:       #가자 중요한 단어를 20개만 보여달라
                center_word_nums.append(word_num)

            # 위의 for 문 대신 아래의 리스트 내포를 이용할 수 있다.
            # center_word_nums = [word_num
            #                     for word_num in ordered_centroids[cluster_num,
            #                                                       :20]]

            center_words = []

            for word_num in center_word_nums:
                center_words.append(words[word_num])

            # 위의 for 문 대신 아래의 리스트 내포를 이용할 수 있다.
            # center_words = [words[word_num] for word_num in center_word_nums]
            print("군집 {}: {}".format(cluster_num, ", ".join(center_words)))
            print("군집 {}: {}".format(cluster_num, ", ".join(center_words)), file=output)
            print()
        print()
        print(model.labels_, file=output)
    print()
    

def main():
    
    documents = read_documents()
    doc_term_mat, words = build_doc_term_mat(documents)
    model = get_flat_clusters(doc_term_mat)      # 러닝의 아웃풋은 모델(="모형","흉내") --> model  머신러닝에서 많이 사용하는 용어
    print(model.labels_)   # 문서별로 어떤 그룹에 해당하는지 확인 가능함. .labels_
                                        # http://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html#sklearn.cluster.KMeans
    output_file=make_file_name()
    
    print_centroid_words(model,words,output_file)
    

# 실행
main()
# Out:
# Initialization complete
# Iteration  0, inertia 675.757
# Iteration  1, inertia 395.114
# Iteration  2, inertia 391.966
# Iteration  3, inertia 390.308
# Iteration  4, inertia 389.679
# Iteration  5, inertia 389.496
# Iteration  6, inertia 389.094
# Iteration  7, inertia 388.899
# Iteration  8, inertia 388.799
# Iteration  9, inertia 388.503
# Converged at iteration 9
# Initialization complete
# Iteration  0, inertia 695.250
# Iteration  1, inertia 400.610
# Iteration  2, inertia 397.217
# Iteration  3, inertia 396.128
# Iteration  4, inertia 395.917
# Iteration  5, inertia 395.737
# Converged at iteration 5
# Initialization complete
# Iteration  0, inertia 450.253
# Iteration  1, inertia 427.021
# Iteration  2, inertia 423.067
# Iteration  3, inertia 420.427
# Iteration  4, inertia 418.435
# Iteration  5, inertia 418.224
# Iteration  6, inertia 418.052
# Iteration  7, inertia 417.843
# Iteration  8, inertia 417.772
# Iteration  9, inertia 417.713
# Iteration 10, inertia 417.686
# Iteration 11, inertia 417.661
# Converged at iteration 11
# Initialization complete
# Iteration  0, inertia 684.287
# Iteration  1, inertia 401.298
# Iteration  2, inertia 397.414
# Iteration  3, inertia 396.139
# Iteration  4, inertia 395.442
# Iteration  5, inertia 394.248
# Iteration  6, inertia 393.524
# Iteration  7, inertia 393.052
# Iteration  8, inertia 392.368
# Iteration  9, inertia 392.305
# Converged at iteration 9
# Initialization complete
# Iteration  0, inertia 689.702
# Iteration  1, inertia 400.928
# Iteration  2, inertia 399.193
# Iteration  3, inertia 398.772
# Iteration  4, inertia 398.595
# Converged at iteration 4
# Initialization complete
# Iteration  0, inertia 670.042
# Iteration  1, inertia 397.490
# Iteration  2, inertia 394.121
# Iteration  3, inertia 392.298
# Iteration  4, inertia 391.211
# Iteration  5, inertia 390.681
# Iteration  6, inertia 390.561
# Iteration  7, inertia 390.443
# Converged at iteration 7
# Initialization complete
# Iteration  0, inertia 689.948
# Iteration  1, inertia 404.425
# Iteration  2, inertia 402.542
# Iteration  3, inertia 401.985
# Iteration  4, inertia 401.310
# Iteration  5, inertia 401.102
# Iteration  6, inertia 400.968
# Converged at iteration 6
# Initialization complete
# Iteration  0, inertia 664.670
# Iteration  1, inertia 395.023
# Iteration  2, inertia 392.668
# Iteration  3, inertia 391.259
# Iteration  4, inertia 390.290
# Iteration  5, inertia 389.812
# Iteration  6, inertia 389.546
# Iteration  7, inertia 388.951
# Iteration  8, inertia 388.284
# Iteration  9, inertia 388.183
# Iteration 10, inertia 388.081
# Iteration 11, inertia 387.974
# Converged at iteration 11
# Initialization complete
# Iteration  0, inertia 688.199
# Iteration  1, inertia 400.444
# Iteration  2, inertia 397.675
# Iteration  3, inertia 397.070
# Iteration  4, inertia 396.986
# Converged at iteration 4
# Initialization complete
# Iteration  0, inertia 682.913
# Iteration  1, inertia 400.277
# Iteration  2, inertia 397.148
# Iteration  3, inertia 395.645
# Iteration  4, inertia 395.104
# Converged at iteration 4
# [ 4 33 27  3 28  7  9 35 10 39 38 37 22  9 15 21 18 17 16  8 23 38  2  6 38
#   2  4 17  2  8 25 22 11 10  6 19 20 25  6 20 26  6  6 29 39 38  6  6 38 19
#   2 38 24  3 39 38 10 32  5 38 11 31 32  6 32 19 32 38 32  5 17 28 10 17  8
#  23 17 31 14 35 12 19 20 17 28  2 19 28  4 34  6 25 25  2 19  2 32 32 10 32
#  26 31 32 31 31  1 19 22 35 38 14  8 19 38 20 23 12 13 13 23 10 13 13 13 19
#  36 13 12 13 36 13 12 12 32  4 33 27  3 28  7  9 35 10 39 38 37 22  9 15 21
#  18 17 16  8 38 20  5  1 34 20 34 11  1 20  3 37 20 24 28 11 25 28 20 23  4
#  19 31 32 32 11 39  3 32 26 32 25 31 25 28  2  4 37 37  9 32 12 13 13 36 13
#  12 13 13 24 13 24 13 24 36 13 24 13 24 36  4 33 27  3 28  7  9 35 10 39 38
#  37 22  9 15 21 18 17 16  8 13 36 32 13 12 13 12 35 32 13 13 29 24 13  0 24
#  36 13 24 13  3 13  2 11  2  3 19 26 11  2 38 38 10 32 34 25  6 32 17 19 36
#  31 31  1 14  1 34 22 32 19 24 24 12 31 36 38 13 13 13 36 14 24  7  2 25  2
#  16 31 25  6 11 14 25  6  8 11 12  3 20  9 25 35 31 38 17 38 32 22 38  9 26
#  34 35 38  4  9 17 20 26 20 20 26 31 24  8 20 32 32 20 20 20 24 39 24 31 20
#  10 20  4 19  4  2  6  2  2  5  2 29  2  4  2 37 11 10  6 11  9  2 14 31 32
#   9 10 11  3  3 10 33 32  1 32 34 20 13 14 32 11  2 31  2 32  2 22 32 25 23
#  14 38 11 32 11 32 14 22 32 32  2 29 20 39 32 19 14 13 17 38 26  6  2  6 23
#  22 32 38 31  1 32 12  4 33 27  3 28  7  9 35 10 39 38 37 22  9 15 21 18 17
#  16  8 32 32 23  1 38 32 17  7 19 12 38  8  6 37 11  6 32 14 32 25 32 12 30
#  20 25 30 28 23 20 25 30  6  6 30 30 32 19 32  8  2 13 13 14 13 13 13 13 17
#  34 13 13 13 13 24 13 13 12 13 10 24 19 19  2 26 24 19 17 23 19 23  4 19 38
#  23 17 31 23 23 19]
# 군집별 중심 어휘
#
# 군집 0: 이익금, 선생, 부당, 청구, 광고비, 파기, 민사소송, 원장, 퇴원, 퇴직금, 부분, 동의서, 계약, 보너스, 신고, 가능, 지급, 소송, 인수, 인계
#
# 군집 1: 임금, 체불, 통상, 상황, 폐업, 노래방, 대표, 회사, 월급, 프로, 일주일, 직원, 도산, 법인, 연락, 내일, 복직, 휴직, 지급, 근로계약서
#
# 군집 2: 연차, 사용, 수당, 퇴사, 입사, 근무, 발생, 가능, 지급, 회사, 인원, 계산, 기준, 올해, 이번, 궁금, 9월, 현재, 만약, 출산
#
# 군집 3: 필요, 신고, 퇴직금, 기간, 처리, 경우, 중간, 입사, 가게, 사업주, 고용보험, 근로자, 서류, 공백, 현행, 건강보험, 노동법, 규정, 상실, 이때
#
# 군집 4: 지급, 퇴직금, 월급, 상태, 퇴직, 수익, 이분, 하지, 리스료, 불량자, 신용, 4대보험, 세무서, 손해, 차량, 회사, 이경우, 추가, 방법, 신고
#
# 군집 5: 계약, 연장, 발생, 종료, 회사, 7월, 취직, 단위, 20일, 최대, 정직, 상세, 이직, 전환, 참가, 시도, 규정, 일부, 전달, 차례
#
# 군집 6: 시간, 근무, 연장, 수당, 근로, 근무시간, 야간, 월급, 휴일, 휴게, 계산, 조건, 얼마, 이상, 회사, 오후, 학원, 금액, 제외, 일급
#
# 군집 7: 퇴직, 1일, 11월, 28일, 연금, 시작, 최저임금, 2월, 얼마, 근무, 예정, 4월, 제출, 입사, 퇴사, 보기, 보관, 보고, 병원장, 보건
#
# 군집 8: 통장, 퇴직금, 이번, 화사, 차이점, 수령, 세금, 차이, 월급, 은행, 내역, 이익, 퇴사, 체당, 회사, 학원, 대표, 4대보험, 새마을금고, 주장
#
# 군집 9: 토요일, 점심시간, 격주, 월급, 평일, 오전, 오후, 최저임금, 세전, 계산, 퇴근, 근무, 출근, 동일, 기준, 시간, 여야, 적용, 금요일, 얼마
#
# 군집 10: 시간, 가입, 4대보험, 금액, 인지, 사업장, 보험, 주휴수당, 급여, 5인, 이상, 근무, 하루, 제가, 산재보험, 기본급, 부담, 감사, 점심시간, 미만
#
# 군집 11: 근로계약서, 작성, 알바, 처음, 시작, 번호, 당장, 종이, 뒷자리, 몇일, 손해배상, 생각, 효력, 기억, 전화, 사본, 문자, 월급, 주말, 지금
#
# 군집 12: 병원, 수술, 산재, 일반, 신청, 절단, 진료, 전국, 가능, 소속, 처리, 피부염, 궁금, 반장, 종합병원, 어깨, 가정집, 얼굴, 한도, 진정서
#
# 군집 13: 산재, 처리, 치료, 회사, 병원, 근로자, 공상, 수술, 입원, 산재보험, 작업, 가능, 근무, 정도, 병원비, 화상, 신청, 업체, 출근, 골절
#
# 군집 14: 육아휴직, 취업, 실업, 상황, 출산휴가, 준비, 회사, 급여, 퇴사, 입사, 원래, 아이, 계약, 사정, 이직, 연계, 퇴직금, 퇴직, 출산, 계약서
#
# 군집 15: 반영, 연차, 인사과, 잔여, 한마디, 잘못, 실수, 연락, 원래, 지금, 발생, 상태, 경우, 회사, 병원장, 병행, 희망, 병원, 병원비, 병명
#
# 군집 16: 정산, 활로, 추공, 감사합니다, 쉬는시간, 상시, 1시간, 이상, 5인, 상여금, 저녁, 근무, 점심시간, 최저임금, 기준, 근로자, 퇴직금, 시간, 안녕하세요, 회사
#
# 군집 17: 신고, 알바, 사람, 재판, 사장, 노동부, 조치, 임금, 안사람, 와중, 이의신청, 체불, 액체, 법적, 방식, 전단지, 단기, 도움, 아무것, 제때
#
# 군집 18: 주오, 근속, 근무, 현재, 실업, 하루, 월급, 시간, 급여, 병력, 병렬, 병명, 병원, 보기, 병가, 별말씀, 병원장, 병행, 보건, 보고
#
# 군집 19: 퇴직, 퇴직금, 기본급, 월급, 금액, 근무, 공제, 사장, 회사, 병가, 계산, 연말정산, 4대보험, 연락, 판매, 노동청, 정도, 급여, 울산, 퇴사
#
# 군집 20: 해고, 수당, 부당, 예고, 통보, 회사, 구제, 복직, 사유, 근로계약서, 경우, 통지, 급여, 근무, 이후, 근로자, 임금, 상당액, 입사, 이상
#
# 군집 21: 8월, 1일, 실업, 바람, 요번, 급여, 이전, 권고, 28일, 사직, 확인, 그때, 고용보험, 회사, 근무, 직장, 2월, 안녕하세요, 정도, 보기
#
# 군집 22: 퇴사, 직장, 자발, 시간, 급여, 동안, 이경우, 실업, 따뜻, 거주지, 트러블, 상황, 통근, 발생, 한마디, 상사, 정당, 판단, 다음날, 이직
#
# 군집 23: 수습, 기간, 회사, 4대보험, 퇴직금, 입사, 퇴사, 가입, 근무, 근로계약서, 사업자, 1월, 적용, 당일, 스케줄, 경리, 19일, 중순, 개인, 새벽
#
# 군집 24: 신청, 휴업, 급여, 요양, 보상, 승인, 병원비, 산재, 연락, 이용, 금전, 부당, 보상금, 실업, 청구, 퇴사, 최초, 구제, 적용, 공단
#
# 군집 25: 휴가, 발생, 연차, 유급, 무급, 일수, 내용, 근무, 건지, 경우, 궁금, 정산, 관련, 퇴사, 근무자, 출산휴가, 미만, 사용, 가입, 급여
#
# 군집 26: 잔업, 시간, 근무, 수당, 하루, 기본급, 계산, 평일, 일당, 지급, 사업장, 거의, 아래, 회사, 경우, 추가, 토요일, 만근, 아침, 부탁
#
# 군집 27: 에세, 목금, 결제, 대응, 승인, 구두, 휴가, 말씀, 사용, 경우, 보관, 보름, 보니, 보너스, 보기, 희망, 보고, 보복, 병행, 병원장
#
# 군집 28: 퇴직금, 월말, 의사, 올해, 입사, 퇴사, 이상, 생각, 보기, 마당, 대답, 당장, 나중, 녹음, 날짜, 경우, 지급, 계약서, 우편, 상태
#
# 군집 29: 야근, 포괄, 누나, 지금, 수당, 기록, 연봉, 신고, 월급, 일급, 이상, 다운, 퇴직금, 디자인, 정공, 패션, 두리, 문제, 학년, 모집
#
# 군집 30: 노조, 설립, 가능, 무기, 대행, 구분, 새마을금고, 조합원, 절차, 정규, 계약, 직원, 가입, 비용, 노동조합, 임원, 창립, 대회, 노조원, 방법
#
# 군집 31: 계약, 만료, 실업, 기간, 급여, 퇴직금, 정규, 계약서, 근무, 회사, 퇴사, 근로, 직장, 입사, 월급, 연봉, 파견, 연장, 위탁, 작성
#
# 군집 32: 직원, 근무, 출근, 회사, 월급, 시간, 매니저, 포함, 공장, 수당, 사장, 퇴직금, 신고, 시급, 상여금, 퇴근, 궁금, 월요일, 아르바이트, 주차장
#
# 군집 33: 유족, 수급, 제목, 순위, 보상, 급여, 궁금, 보기, 보관, 보고, 보건, 병원장, 병행, 보니, 병원비, 병원, 병명, 병렬, 병력, 병가
#
# 군집 34: 사직서, 어린이집, 사직, 권고, 제출, 퇴사, 회사, 2월, 압박, 해고, 근무, 구하기, 상배, 정신, 교사, 이행, 통지서, 비용, 취소, 업무
#
# 군집 35: 세금, 정확, 얼마, 퇴직금, 계산, 부탁, 근무, 상한선, 정도, 시반, 의미, 금액, 연봉, 오일, 기전, 최저임금, 식대, 급여, 실제, 동계
#
# 군집 36: 허리, 디스크, 병원, 판정, 검사, 통증, 목수, 원청, 시술, 재가, 휴식, 다리, 처리, 수술, 가능, 장해, 산재보험, 형틀, 치료, 산재
#
# 군집 37: 작성, 근로계약서, 변경, 급여, 입사, 계약서, 재작성, 상태, 인상, 서면, 통보, 위반, 근로자, 근로기준법, 내역, 처벌, 조항, 내용, 임금, 근로
#
# 군집 38: 시급, 주휴수당, 시간, 최저, 근무, 휴일, 알바, 하루, 신고, 계산, 포함, 야간, 1월, 수당, 정도, 월급, 근로계약서, 일요일, 가능, 식비
#
# 군집 39: 주말, 시간, 계산, 소정, 알바, 근로시간, 일수, 결근, 근로, 포함, 하루, 퇴직금, 주중, 정도, 일시, 평일, 근무, 저녁, 적성, 대전
