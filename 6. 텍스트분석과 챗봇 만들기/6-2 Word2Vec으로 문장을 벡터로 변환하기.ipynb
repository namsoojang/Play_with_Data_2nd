# %% [markdown]
# # Word2Vec으로 문장을 벡터로 변환하기
#
# * Word2Vec 문장 내부의 단어를 Vector로 변환하는 도구
#     * 단어 임베딩(Word Embedding: 텍스트를 구성하는 하나의 단어를 수치화하는 방법
#     * 단어와 단어의 유사도를 확인
# * Gensim 설치
#     * 자연어 처리를 위한 라이브러리

# %%
import codecs
from bs4 import BeautifulSoup
from konlpy.tag import Twitter
from gensim.models import word2vec

# %%
# utf-16 인코딩/파일 열기
fp = codecs.open("BEXX0003_short.txt", "r", encoding="utf-16")
soup = BeautifulSoup(fp, "html.parser")
body = soup.select_one("body > text")
text = body.getText()

# %%
twitter = Twitter()
results = []
lines = text.split("\n")
for line in lines:
    # 형태소 분석
    malist = twitter.pos(line, norm=True, stem=True) # 동사/형용사는 기본형으로 변환
    r = []
    for word in malist:
        # 조사, 어미, 구두점은 제외
        if not word[1] in ["Josa", "Eomi", "Punctuation"]:
            r.append(word[0])
    rl = (" ".join(r)).strip()
    results.append(rl)
    print(rl)
# Out:
# 제 1 편 어둠 발 소리
# 서다 序
# 1897 년 한가위
# 까치 들 울타리 안 감나무 와 아침 인사 하다 전 무색 옷 댕기 꼬리 늘 아이 들 송편 입 물 마을 길 쏘다 기쁘다 날뛰다 어른 들 해 중천 좀 기울다 무렵 이 래야 차례 치르다 하다 성묘 하다 하다 이웃 끼리 음식 나누다 보다 한나절 넘다 이 때 타작 마당 사람 들 모이다 시작 하다 들다 뜨다 시작 하다 남정 노인 들 아낙 들 채비 아무래도 더 디어 데 그렇다 수 없다 것 식구 들 시중 음식 간수 끝내다 제 자신 치장 남아 있다 이 바람 고개 무겁다 벼 이삭 황금 빛 물결 이루다 들판 마음 놓다 새떼 들 모여들다 풍 성 향연 벌이다
# 후우 이이 이 놈 새떼 들 극성 새 쫓다 할망구 와삭 와삭 풀발 선 출입 옷 갈아입다 타작 마당 굿 보고 있다 것 추석 마을 남녀 노유 사람 들 뿐 아니다 강아지 돼지 소나 말 새 들 시궁창 드나드 쥐 새끼 포식 날인 보다
# 빠르다 장단 꽹과리 소리 느리다 장단 두다 중 여음 울리다 징 소리 타작 마당 거리 멀다 최 참판 댁 사랑 흐느낌 슬프다 들려오다 농부 들 지금 꽃 달리다 고깔 흔들다 신명 내다 괴롭다 하다 일상 日常 잊다 굿 놀이 열중 하다 있다 것 최 참판 댁 섭섭찮 전곡 錢穀 이 나가다 풍년 미치다 못 하다 실 평작 임 틀림 없다 것 모처럼 허리 끈 풀다 쌀밥 식구 들 배 두드리다 테 하루 근심 잊다 만 하다 것
# 이 날 수수 개비 꺾다 아이 들 매 맞다 않다 여러 달 솟다 증 素症 풀다 느 긋다 하다 늙은이 들 뒷간 출입 잦다 힘 좋다 젊은이 들 벌써 읍내 가다 없다 황소 하다 마리 끌 돌아오다 꿈 꾸미다 읍내 씨름판 몰다 간 것
# 최 참판 댁 사랑 무인 지경 적막 하다 햇빛 맑다 뜰 비치다 사람 들 모두 어디 가다 버리다 새롭다 바르다 방문 장지 낯설다
# 달 산마루 떨어지다 나오다 아직 붉다 머 않다 창백 질 것 희다 번 덕이 섬진강 저 켜다 전라도 땅 이켠 경상도 땅 너 그렇다 그 어진 능선 확실하다 윤곽 드러내다
# 난간 걸터 앉다 달 뜨다 광경 지켜보다 구천이 눈 번득 빛 내다 달빛 이다 눈물 이다 아니다 참담 소망 이다 모르다
# 1 장 서희 西姬
# 김 서방 떠들다 대다
# 해마다 애 믹이 사람 들 딱 정해지다 있다 말
# 누가 애 믹 싶다 믹이 기요
# 말 마르다 소가 죽다 심다 다리 뿌 일 못 하다 심다 혼사 있다 장리 빚 내다 심다 나중 무슨 핑계 대다 기 고
# 그러나 김 서방 넘다 보고 있다 상대
# 내 핑계 댄다믄 벼락 맞다 일 기요 그렇다 애맨 소리 안 하다 기이 좋겄 구마 볼멘소리 대꾸 하다
# 이렇다 못 묵다 못 묵다 양새 끼다 나무 매다 어디 사람 하다 짓다
# 저 이르다 저러다 통사정 해오다 작 作人 들다 상대 하다 보다 유순 김 방도 짜증 나 모양
# 며칠 전 최 참판 댁 안팎 시끄럽다 늘 비 하다 이어진 고방 끊임없다 볏섬 들어가다 한편 읍내 곡식 실어 내다 바람 하인 들 지치다 근력 좋다 마구간 말 외양간 살찐 황소 몸살 날 지경 이다 행랑 행랑 멀다 곳 가깝다 곳 모이다 온 마름 작 이 득실득실 판 있다 그 들 위해 크다 가마솥 쉬다 새 없이 밥 삶다 하다
# 여보 시오 내 말 좀 들다 보라
# 들다 마나 뻔하다 머 축 난 것 틀림 없다
# 아 그렇다 하다 말 아니다
# 만분 해보다 그 말 그 말 이지 머
# 이렇다 딱하다 데 있다 돌 하나 들어가다 싶다 올빼미 겉 눈 크게 뜨다
# 크게 뜨믄 소용 있다 눈 뵈 말 이지
# 그렇다 그라믄 우리 거부 지기 쑤셔넣었겄소 축 날 리가 없다 말 이
# 담장 밖 다투다 막걸리 사발 들이켜다 걸걸 한 목소리 이다
# 봉순 흐흐 …… 흐 나 여기 있다
# 볏섬 지다 나르다 구천 다리 뒤 숨다 살금살금 걸어오다 자그마하다 계집아이 얼굴 내미다 앙증 스럽다 건강하다 보이다 아이 나이 다섯 살 장차 어찌 되다 현재 로서 최 치수 하나 뿐 혈육 이다 서희 어머니 별당 아씨 닮다 들다 하다 할머니 모습 있다 하다 안존 하다 못 것 나이 탓 하다 기상 강하다 것 할머니 편의 기질 하다
# 서희 찾다 두리번거리다 있다 봉 순이 건너오다 하다 서희 맴 돌다 구천이 앞 달아나다 끼룩끼룩 웃다
# 넘어지다 믄 큰일 난 캤는데 애기 씨
# 봉 순이 울상 지다 날개 짓 배우다 시작 하다 새 새끼 서희 이리 뛰다 저리 뛰어다니다 좀체 봉 순이 잡히다 하다 않다 유록빛 꽃 자 주선 두르다 조그마하다 꽃신 퍽으 날렵하
# 애기 씨
# 일꾼 들 발 걸리다 넘어지다 않다 이 광경 마님 들다 키 큰일 겠다 하다 조마조마 하다 봉 순이 곯려주려 서희 다시 구천이 다리 방패 삼다 뒤 숨다
# 애기 씨 이르다 심 안 되다
# 이번 걸음 멈추다 구천이 말 하다
# 넘어지다 않다
# 깡충 뛰다 구천이 땀 젖다 잠방이 뒷자락 심술궂 잡아당기다
# 이르다 심 안 되다
# 나다 막 소리 타 이르다 구천이 볏섬 진 채 몸 돌리다 봉 순이
# 애기 씨 뫼시 별당
# 한참 다시
# 별당 가다 놀다 하다 말 끝 맺다 서희 구천이 잠방이 잡고 늘어지다 오도 가도 못 하다 방해 하다
# 애기 씨 가다 사 까다 사 입시
# 꾀 듯이 봉 순이 손 잡다 뿌리
# 나 여기 놀 테
# 일질 넘어지다
# 구천이 목소리 역시 나직 하다
# 싫다 안 갈다 테
# 마님 보시 꾸중 하다
# 나 할머니 무섭다 않다
# 잠방이 자락 겨우 놓다 준 서희 구천이 놓다 보다 제 주장 뚜렷 나타내다 그러나 할머니 무섭다 무섭다 모양
# 구천이 바보 덩신 중놈
# 욕 하다 달아나다 봉 순이 그 뒤 쫓다 뛰어가다 짧다 저고리 도련 밑 늘어지다 빨강 댕기 할랑할랑 그네 뛰다 아이 들 모습 사라지다
# 볏섬 짊 어진 채 아이 들 뒷모습 우두커니 바라보다 구천이 고방 쪽 걸음 옮기다
# 으윽
# 힘 주다 소리 함께 볏섬 고방 바닥 나 동그랗다
# 장골 나락 하다 섬 지고 맥 못 추다 우 찌 되다 일
# 들이다 볏섬 돌이 함께 맞다 잡다 고방 쌓다 올리다 삼수 갈고리 볏섬 걸 말 하다
# 땀 좀 닦다
# 이번 돌이 딱하다 말 하다 구천이 지푸라기 엉 겨 붙다 잠방이 소매 끌어당기다 땀 닦다 얼굴빛 푸르다 눈 움푹 패어 있다
# 갈고리 걸다 기다 하다 돌이 땀 닦다 구천이 멍청하다 쳐다보다 있다 삼수 코 힝 푼 콧물 묻다 손 옷 문 지르다
# 니 그 라다 몸 베릴
# 땀 닦다 구천이 삼수 입매 쳐다보다 삼수 다시 무슨 짓 하다 우리 좀 알 싶다
# 멀리 무슨 소리 나다 서다 있다 구천이 눈 다음 순간 거치다 빛나다
# 삼수 더 이상 말 걸다 않다 돌이 말 하다 않다 그 들 영 치기
# 볏섬 들어오다 린다 그렇다 날씨 이야기 부 추다 벼 싣다 고온 박서방 혹 금년 더 커지다 둥 하다 삼수 돌이 무관심하다 척 하다 애 쓸다 삼수 곁눈질 구천이 기색 살피다
# 어서 가다 나락 지다 아 무도 해 잡다 매다 안 하다 하다 등 받다 쓰다 마대 고방 바닥 줍다 어깨 걸 구천이 기다 팔 늘다 뜨다 리 돌아서다 나가다
# 싫다 대두 싫다 아버지 싫다 말
# 서희 발 동동 구르다 침모 봉순 어미 옷고름 여 주다 달래다 있다 구천이 눈 내리다 깔다 그 들 옆 지나가다
# 마님 말씀 하싰 습 다 나 으리 문안 드리다 중년 접다 봉순 네 살빛 희다 좀 비대 펴다 서희 봉순 치맛 자락 잡다 두 만 집 강아지 보다 갈다 테
# 마님 아시 믄 큰일 나다 꾸중 하다 봉순 어서 애기 씨 뫼시 사랑 가다 서희 등 도닥거리 봉순 네 딸 이르다
# 아버 진 싫다 고홈 고홈 하다
# 목 뽑다 기침 하다 치수 시늉 내다 봉순 네 웃음 참다
# 큰일 날 소리 봉순 어서
# 애기 씨 가입 시
# 봉 순이 싫다 부스스 말 하다
# 그라믄 사랑 마당 지다 데리다 리지
# 봉순 네 병아리 몰다 뒤 아이 들 몰다 내다 서희 민적 민적 하다 서도 가기 간다
# 이제 갈다
# 고개 끄덕 봉순 네 올려다보다 서희 눈 겁 잔뜩 실리다
# 사랑 앞뜰 햇빛 화사하다 비치 있다 돌담 용마루 높이 만큼 키 지니다 옥매 화 매초롬 회색 가지 뻗다 목련 삼화 석류나무 치자나무 마치 봄날 햇빛 받다 노곤 것 보이다 이미 순환 멈추다 것 메다 버리다 나뭇잎 얼마 남지 않다 잎 추다 버리다 파초 역시 누릿누릿 시들다 있다 것 같다
# 긴장 하다 땀 나 손 잡고 마주 보고 있다 아이 들 결심 하다 치수 기다 방 앞 간다 목소리 가다 다듬다 봉 순이
# 낫다 마님 애기 씨 물다 싰습 다 마님 문안 드리다 하다 오싰습니
# 몇 번 입속 굳다 보다 줄줄 외다 나오다 방안 밭은기침 소리 나다 기침 멎다 뒤
# 들어오다 너
# 음산 하다 울리다
# 신돌 위 작다 신발 나란히 벗다 서희 마루 올라가다 서희 얼굴 해쓱 지다 있다 봉 순이 열다 주다 방문 서희 방안 들어가다 때 방금 일어나다 마주 하다 치수 서안 書案 앞 앉다 있다 아랫목 까다 놓다 이부자리 반 쯤 걷다 있다 벼룻 집의 벼루 연적 붓 두루 마리 먼지 뿌옇 앉다 있다 문갑 위 상감 청자 향로 아무렇다 쌓다 올려놓다 서다 책 위 먼지 뿌옇 앉다 있다
# 바깥 날씨 차다
# 길다 찢어지다 눈 서희 응시 하다 물다 서희 그 말 귀 닿다 않다 것 붉다 치마 활짝 펴다 나붓이 절 하다
# 요즘 아버님 병환 차도 있다 신지 문안 드리다
# 봉 순이 그러하다 것 목청 가다 다듬다 외다 투 억양 없다 소리 질렀
# 괜찮다 서희 밥 자다 먹다 감기 안 들다
# 갈기갈기 갈라지다 여러 개 쇠 서로 부딪치다 때 나 것 같다 목소리 여전하다 음산 하다 그 서희 공포 심 충분하다 알 있다 것 같다 그렇다 그것 풀다 노력 없다 싸 늘다 비정 눈 서희 응시 있다 것 서희 아버지 눈 피 하다 하다 당장 천둥 벼락 떨어지다 것 애처롭 그 마주 보다 채 고개 저었 치수 웃다 그 웃음 도리어 서희 마음 얼다 붙다 하다 서희 로부터 시선 돌리다 치수 서안 위 펴다 치다 놓다 책 갈피 넘기다 허약 체질 비 하다 뼈마디 굵다 펴다 그러나 가엾다 만큼 여 위고 창백 그 손 책갈피 누르다 눈 글자 더듬어 내려가다 손 뿐 뜰 아래 물기 잃다 목련 앙 상한 가지 그러나 동정 받다 수 있다 비참 느낌 이기 도리어 상대 견디다 수 없다 숨 막히다 견디다 수 없다 결국 은 공포 심 불러일으키다 하다 강하다 분위기 그 내어뿜 있다 어떻다 일 감동 되다 않다 눈빛 철저하다 스스로 거부 하다 눈빛 눈빛 그렇다 것 아니다 뼈 남다 몸 전체 거부 로써 남 학대 하다 분위기 응결 이다
# 일단 방 들어오다 뒤 나가다 좋다 말 떨어지다 않다 이상 서희 일어서다 수 없다 숨소리 죽 그래서 가냘픈 가슴 더 뛰다 양 어깨 숨 쉬다 수 없다 움직이다 못 하다 것 어리다 것 얼마나 크다 고통
# 이따금 책장 넘기다 소리 나다
# 길 상
# 별안간 귀청 찢다 것 같다 고함 서희 용수철 앉은자리 튀다
# 길 상
# 예
# 대답 함께 급하다 뛰다 발 소리 들려오다 뜰 아래 낫다 마님 부르셨습
# 앳된 소년 목소리 이다
# 방이 왜 이리 차다
# 곧 불 지다 피다
# 내 지금 방이 왜 이리 차다 묻다 않다
# 푸른 정맥 이마 빼기 부풀 어 올르다 서희 얼굴 질 린다
# 예 지금 곧 곧 불 지다 피다
# 이 놈 방이 왜 이리 차다 물다 고얀 놈
# 잘못 하다 낫다 마님
# 소년 겁 먹다 소리 내다 매양 당하다 때문 길 들 사냥개 뒤쪽 달려가다 장작 한아름 안고 뛰어오다
# 으흐 컥
# 신경질 심하다 기침 유발 하다 치수 수건 꺼내다 입 막다 기침 멎다 않다 눈 활짝 벌어지다 붉다 눈알 불다 나오다 기침 잠시 틈 용 납치 않다 그 달겨 다 입 막다 상체 흔들다 고독 모습 이다

# %%
# File
wakati_file = 'toji.wakati'
with open(wakati_file, 'w', encoding='utf-8') as fp:
    fp.write("\n".join(results))

# %%
# Word2Vec 모델 만들기
data = word2vec.LineSentence(wakati_file) # 텍스트 읽기
model = word2vec.Word2Vec(data, size=200, window=10, hs=1, min_count=2, sg=1)
model.save("toji.model")
print("ok")
# Out:
# ok

# %%
model2 = word2vec.Word2Vec.load("toji.model")
# most_similar() 유사한 단어 확인 method
model2.most_similar(positive=["땅"])
# Out:
# /Users/tomato/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# [('번', 0.9992644786834717),
#  ('켜다', 0.99924236536026),
#  ('붉다', 0.9992011189460754),
#  ('아이', 0.9991986751556396),
#  ('가지', 0.9991936683654785),
#  ('않다', 0.9991858005523682),
#  ('아직', 0.9991702437400818),
#  ('들려오다', 0.9991583824157715),
#  ('질', 0.9991562962532043),
#  ('소리', 0.9991493225097656)]

# %%
model2.most_similar(positive=["집"])
# Out:
# /Users/tomato/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('펴다', 0.9993793964385986),
#  ('가다', 0.9993119239807129),
#  ('손', 0.999287486076355),
#  ('좀', 0.9992727041244507),
#  ('책', 0.9992713928222656),
#  ('그러나', 0.999232292175293),
#  ('넘기다', 0.9991901516914368),
#  ('들', 0.9991891384124756),
#  ('이다', 0.9991840720176697),
#  ('치다', 0.9991788864135742)]
